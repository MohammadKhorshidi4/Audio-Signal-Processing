# %%
from scipy.io import wavfile
samplerate, data = wavfile.read("DialedSequence_NoNoise.wav")
#loading the sound

# %% [markdown]
# # Finding the places Where the buttom is pushed & Which one is pushed

# %%
import scipy.io
from scipy import signal
from matplotlib import pyplot as plt
import math
dokmeh=[]
dokmeh1=[]
qq=0
ww=0
mat = scipy.io.loadmat('FREQUNCIES.mat')
f1209=mat.get('f1209')
f1336=mat.get('f1336')
f1477=mat.get('f1477')
f1633=mat.get('f1633')
f697=mat.get('f697')
f770=mat.get('f770')
f852=mat.get('f852_1')
f941=mat.get('f941')
L=len(data)
o=math.ceil(L/1000)
for i in range(o):
    q=1000*(i-1)
    p=1000*i-1
    data1=data[q:p]
    maxi=max(abs(data1))
    data1=data1/maxi
    f1=signal.lfilter(f1209[0,:],1,data1)
    f2=signal.lfilter(f1336[0,:],1,data1)
    f3=signal.lfilter(f1477[0,:],1,data1)
    f4=signal.lfilter(f1633[0,:],1,data1)
    f5=signal.lfilter(f697[0,:],1,data1)
    f6=signal.lfilter(f770[0,:],1,data1)
    f7=signal.lfilter(f852[0,:],1,data1)
    f8=signal.lfilter(f941[0,:],1,data1)
    Y1=np.fft.fft(f1)
    Y2=np.fft.fft(f2)
    Y3=np.fft.fft(f3)
    Y4=np.fft.fft(f4)
    Y5=np.fft.fft(f5)
    Y6=np.fft.fft(f6)
    Y7=np.fft.fft(f7)
    Y8=np.fft.fft(f8)
    L1=len(Y1)
    L2=len(Y2)
    L3=len(Y3)
    L4=len(Y4)
    L5=len(Y5)
    L6=len(Y6)
    L7=len(Y7)
    L8=len(Y8)
    P1 = abs(Y1/L1)
    P2 = abs(Y2/L2)
    P3 = abs(Y3/L3)
    P4 = abs(Y4/L4)
    P5 = abs(Y5/L5)
    P6 = abs(Y6/L6)
    P7 = abs(Y7/L7)
    P8 = abs(Y8/L8)
    col=[max(P1),max(P2),max(P3),max(P4)]
    row=[max(P5),max(P6),max(P7),max(P8)]
    mmco=max(col)
    mmro=max(row)
    if mmco>0.06 and mmro>0.06:
        mcol = col.index(mmco)         
        mrow = row.index(mmro)
        if mcol==0 and mrow==0:
            dokmeh=dokmeh+['1']
        elif mcol==0 and mrow==1:
            dokmeh=dokmeh+['4']
        elif mcol==0 and mrow==2:
            dokmeh=dokmeh+['7']
        elif mcol==0 and mrow==3:
            dokmeh=dokmeh+['*']
        elif mcol==1 and mrow==0:
            dokmeh=dokmeh+['2']
        elif mcol==1 and mrow==1:
            dokmeh=dokmeh+['5']
        elif mcol==1 and mrow==2:
            dokmeh=dokmeh+['8']
        elif mcol==1 and mrow==3:
            dokmeh=dokmeh+['0']
        elif mcol==2 and mrow==0:
            dokmeh=dokmeh+['3']
        elif mcol==2 and mrow==1:
            dokmeh=dokmeh+['6']
        elif mcol==2 and mrow==2:
            dokmeh=dokmeh+['9']
        elif mcol==2 and mrow==3:
            dokmeh=dokmeh+['#']
        elif mcol==3 and mrow==0:
            dokmeh=dokmeh+['A']
        elif mcol==3 and mrow==1:
            dokmeh=dokmeh+['B']
        elif mcol==3 and mrow==2:
            dokmeh=dokmeh+['C']
        elif mcol==3 and mrow==3:
            dokmeh=dokmeh+['D']
dokmeh = list(dict.fromkeys(dokmeh))
print(dokmeh)
# Out:
# <ipython-input-72-be1e06eb1f26>:25: RuntimeWarning: invalid value encountered in true_divide
#   data1=data1/maxi
# ['4', '#', '2', '0', '6', 'A', '7', '8', '5', '1', '3', '*', '9', 'D', 'B', 'C']

# %% [markdown]
# # The Bottoms in nonoise were ['4', '#', '2', '0', '6', 'A', '7', '8', '5', '1', '3', '*', '9', 'D', 'B', 'C']

# %% [markdown]
# # For SNR=0dB

# %%
from scipy.io import wavfile
samplerate, data = wavfile.read("DialedSequence_SNR00dB.wav")
#loading the sound

# %%
import scipy.io
from scipy import signal
from matplotlib import pyplot as plt
import math
dokmeh=[]
mat = scipy.io.loadmat('FREQUNCIES.mat')
f1209=mat.get('f1209')
f1336=mat.get('f1336')
f1477=mat.get('f1477')
f1633=mat.get('f1633')
f697=mat.get('f697')
f770=mat.get('f770')
f852=mat.get('f852_1')
f941=mat.get('f941')
L=len(data)
o=math.ceil(L/1000)
for i in range(o):
    q=1000*(i-1)
    p=1000*i-1
    data1=data[q:p]
    maxi=max(abs(data1))
    data1=data1/maxi
    f1=signal.lfilter(f1209[0,:],1,data1)
    f2=signal.lfilter(f1336[0,:],1,data1)
    f3=signal.lfilter(f1477[0,:],1,data1)
    f4=signal.lfilter(f1633[0,:],1,data1)
    f5=signal.lfilter(f697[0,:],1,data1)
    f6=signal.lfilter(f770[0,:],1,data1)
    f7=signal.lfilter(f852[0,:],1,data1)
    f8=signal.lfilter(f941[0,:],1,data1)
    Y1=np.fft.fft(f1)
    Y2=np.fft.fft(f2)
    Y3=np.fft.fft(f3)
    Y4=np.fft.fft(f4)
    Y5=np.fft.fft(f5)
    Y6=np.fft.fft(f6)
    Y7=np.fft.fft(f7)
    Y8=np.fft.fft(f8)
    L1=len(Y1)
    L2=len(Y2)
    L3=len(Y3)
    L4=len(Y4)
    L5=len(Y5)
    L6=len(Y6)
    L7=len(Y7)
    L8=len(Y8)
    P1 = abs(Y1/L1)
    P2 = abs(Y2/L2)
    P3 = abs(Y3/L3)
    P4 = abs(Y4/L4)
    P5 = abs(Y5/L5)
    P6 = abs(Y6/L6)
    P7 = abs(Y7/L7)
    P8 = abs(Y8/L8)
    col=[max(P1),max(P2),max(P3),max(P4)]
    row=[max(P5),max(P6),max(P7),max(P8)]
    mmco=max(col)
    mmro=max(row)
    if mmco>0.06 and mmro>0.06:
        mcol = col.index(mmco)         
        mrow = row.index(mmro)
        if mcol==0 and mrow==0:
            dokmeh=dokmeh+['1']
        elif mcol==0 and mrow==1:
            dokmeh=dokmeh+['4']
        elif mcol==0 and mrow==2:
            dokmeh=dokmeh+['7']
        elif mcol==0 and mrow==3:
            dokmeh=dokmeh+['*']
        elif mcol==1 and mrow==0:
            dokmeh=dokmeh+['2']
        elif mcol==1 and mrow==1:
            dokmeh=dokmeh+['5']
        elif mcol==1 and mrow==2:
            dokmeh=dokmeh+['8']
        elif mcol==1 and mrow==3:
            dokmeh=dokmeh+['0']
        elif mcol==2 and mrow==0:
            dokmeh=dokmeh+['3']
        elif mcol==2 and mrow==1:
            dokmeh=dokmeh+['6']
        elif mcol==2 and mrow==2:
            dokmeh=dokmeh+['9']
        elif mcol==2 and mrow==3:
            dokmeh=dokmeh+['#']
        elif mcol==3 and mrow==0:
            dokmeh=dokmeh+['A']
        elif mcol==3 and mrow==1:
            dokmeh=dokmeh+['B']
        elif mcol==3 and mrow==2:
            dokmeh=dokmeh+['C']
        elif mcol==3 and mrow==3:
            dokmeh=dokmeh+['D']
dokmeh = list(dict.fromkeys(dokmeh))
print(dokmeh)
# Out:
# ['A', '1', '3', 'D', '4', '7', '5', 'B', 'C', '2', '9', '6', '#', '8', '0', '*']

# %% [markdown]
# # The Bottoms in SNR=0dB were ['A', '1', '3', 'D', '4', '7', '5', 'B', 'C', '2', '9', '6', '#', '8', '0', '*']

# %% [markdown]
# # For SNR=10dB

# %%
from scipy.io import wavfile
samplerate, data = wavfile.read("DialedSequence_SNR10dB.wav")
#loading the sound

# %%
import scipy.io
from scipy import signal
from matplotlib import pyplot as plt
import math
dokmeh=[]
mat = scipy.io.loadmat('FREQUNCIES.mat')
f1209=mat.get('f1209')
f1336=mat.get('f1336')
f1477=mat.get('f1477')
f1633=mat.get('f1633')
f697=mat.get('f697')
f770=mat.get('f770')
f852=mat.get('f852_1')
f941=mat.get('f941')
L=len(data)
o=math.ceil(L/1000)
for i in range(o):
    q=1000*(i-1)
    p=1000*i-1
    data1=data[q:p]
    maxi=max(abs(data1))
    data1=data1/maxi
    f1=signal.lfilter(f1209[0,:],1,data1)
    f2=signal.lfilter(f1336[0,:],1,data1)
    f3=signal.lfilter(f1477[0,:],1,data1)
    f4=signal.lfilter(f1633[0,:],1,data1)
    f5=signal.lfilter(f697[0,:],1,data1)
    f6=signal.lfilter(f770[0,:],1,data1)
    f7=signal.lfilter(f852[0,:],1,data1)
    f8=signal.lfilter(f941[0,:],1,data1)
    Y1=np.fft.fft(f1)
    Y2=np.fft.fft(f2)
    Y3=np.fft.fft(f3)
    Y4=np.fft.fft(f4)
    Y5=np.fft.fft(f5)
    Y6=np.fft.fft(f6)
    Y7=np.fft.fft(f7)
    Y8=np.fft.fft(f8)
    L1=len(Y1)
    L2=len(Y2)
    L3=len(Y3)
    L4=len(Y4)
    L5=len(Y5)
    L6=len(Y6)
    L7=len(Y7)
    L8=len(Y8)
    P1 = abs(Y1/L1)
    P2 = abs(Y2/L2)
    P3 = abs(Y3/L3)
    P4 = abs(Y4/L4)
    P5 = abs(Y5/L5)
    P6 = abs(Y6/L6)
    P7 = abs(Y7/L7)
    P8 = abs(Y8/L8)
    col=[max(P1),max(P2),max(P3),max(P4)]
    row=[max(P5),max(P6),max(P7),max(P8)]
    mmco=max(col)
    mmro=max(row)
    if mmco>0.06 and mmro>0.06:
        mcol = col.index(mmco)         
        mrow = row.index(mmro)
        if mcol==0 and mrow==0:
            dokmeh=dokmeh+['1']
        elif mcol==0 and mrow==1:
            dokmeh=dokmeh+['4']
        elif mcol==0 and mrow==2:
            dokmeh=dokmeh+['7']
        elif mcol==0 and mrow==3:
            dokmeh=dokmeh+['*']
        elif mcol==1 and mrow==0:
            dokmeh=dokmeh+['2']
        elif mcol==1 and mrow==1:
            dokmeh=dokmeh+['5']
        elif mcol==1 and mrow==2:
            dokmeh=dokmeh+['8']
        elif mcol==1 and mrow==3:
            dokmeh=dokmeh+['0']
        elif mcol==2 and mrow==0:
            dokmeh=dokmeh+['3']
        elif mcol==2 and mrow==1:
            dokmeh=dokmeh+['6']
        elif mcol==2 and mrow==2:
            dokmeh=dokmeh+['9']
        elif mcol==2 and mrow==3:
            dokmeh=dokmeh+['#']
        elif mcol==3 and mrow==0:
            dokmeh=dokmeh+['A']
        elif mcol==3 and mrow==1:
            dokmeh=dokmeh+['B']
        elif mcol==3 and mrow==2:
            dokmeh=dokmeh+['C']
        elif mcol==3 and mrow==3:
            dokmeh=dokmeh+['D']
dokmeh = list(dict.fromkeys(dokmeh))
print(dokmeh)
# Out:
# ['D', '1', '7', '6', 'A', '3', '5', '4', 'C', '9', '0', '#', '8', 'B', '2', '*']

# %% [markdown]
# # The Bottoms in SNR=10dB were ['D', '1', '7', '6', 'A', '3', '5', '4', 'C', '9', '0', '#', '8', 'B', '2', '*']

# %% [markdown]
# # For SNR=20dB

# %%
from scipy.io import wavfile
samplerate, data = wavfile.read("DialedSequence_SNR20dB.wav")
#loading the sound

# %%
import scipy.io
from scipy import signal
from matplotlib import pyplot as plt
import math
dokmeh=[]
mat = scipy.io.loadmat('FREQUNCIES.mat')
f1209=mat.get('f1209')
f1336=mat.get('f1336')
f1477=mat.get('f1477')
f1633=mat.get('f1633')
f697=mat.get('f697')
f770=mat.get('f770')
f852=mat.get('f852_1')
f941=mat.get('f941')
L=len(data)
o=math.ceil(L/1000)
for i in range(o):
    q=1000*(i-1)
    p=1000*i-1
    data1=data[q:p]
    maxi=max(abs(data1))
    data1=data1/maxi
    f1=signal.lfilter(f1209[0,:],1,data1)
    f2=signal.lfilter(f1336[0,:],1,data1)
    f3=signal.lfilter(f1477[0,:],1,data1)
    f4=signal.lfilter(f1633[0,:],1,data1)
    f5=signal.lfilter(f697[0,:],1,data1)
    f6=signal.lfilter(f770[0,:],1,data1)
    f7=signal.lfilter(f852[0,:],1,data1)
    f8=signal.lfilter(f941[0,:],1,data1)
    Y1=np.fft.fft(f1)
    Y2=np.fft.fft(f2)
    Y3=np.fft.fft(f3)
    Y4=np.fft.fft(f4)
    Y5=np.fft.fft(f5)
    Y6=np.fft.fft(f6)
    Y7=np.fft.fft(f7)
    Y8=np.fft.fft(f8)
    L1=len(Y1)
    L2=len(Y2)
    L3=len(Y3)
    L4=len(Y4)
    L5=len(Y5)
    L6=len(Y6)
    L7=len(Y7)
    L8=len(Y8)
    P1 = abs(Y1/L1)
    P2 = abs(Y2/L2)
    P3 = abs(Y3/L3)
    P4 = abs(Y4/L4)
    P5 = abs(Y5/L5)
    P6 = abs(Y6/L6)
    P7 = abs(Y7/L7)
    P8 = abs(Y8/L8)
    col=[max(P1),max(P2),max(P3),max(P4)]
    row=[max(P5),max(P6),max(P7),max(P8)]
    mmco=max(col)
    mmro=max(row)
    if mmco>0.06 and mmro>0.06:
        mcol = col.index(mmco)         
        mrow = row.index(mmro)
        if mcol==0 and mrow==0:
            dokmeh=dokmeh+['1']
        elif mcol==0 and mrow==1:
            dokmeh=dokmeh+['4']
        elif mcol==0 and mrow==2:
            dokmeh=dokmeh+['7']
        elif mcol==0 and mrow==3:
            dokmeh=dokmeh+['*']
        elif mcol==1 and mrow==0:
            dokmeh=dokmeh+['2']
        elif mcol==1 and mrow==1:
            dokmeh=dokmeh+['5']
        elif mcol==1 and mrow==2:
            dokmeh=dokmeh+['8']
        elif mcol==1 and mrow==3:
            dokmeh=dokmeh+['0']
        elif mcol==2 and mrow==0:
            dokmeh=dokmeh+['3']
        elif mcol==2 and mrow==1:
            dokmeh=dokmeh+['6']
        elif mcol==2 and mrow==2:
            dokmeh=dokmeh+['9']
        elif mcol==2 and mrow==3:
            dokmeh=dokmeh+['#']
        elif mcol==3 and mrow==0:
            dokmeh=dokmeh+['A']
        elif mcol==3 and mrow==1:
            dokmeh=dokmeh+['B']
        elif mcol==3 and mrow==2:
            dokmeh=dokmeh+['C']
        elif mcol==3 and mrow==3:
            dokmeh=dokmeh+['D']
dokmeh = list(dict.fromkeys(dokmeh))
print(dokmeh)
# Out:
# ['3', '2', '5', '6', '4', '0', 'B', '*', '9', '1', '8', '7', 'A', 'D', 'C', '#']

# %% [markdown]
# # The Bottoms in SNR=20dB were ['3', '2', '5', '6', '4', '0', 'B', '*', '9', '1', '8', '7', 'A', 'D', 'C', '#']

# %% [markdown]
# # For SNR=30dB

# %%
from scipy.io import wavfile
samplerate, data = wavfile.read("DialedSequence_SNR30dB.wav")
#loading the sound

# %%
import scipy.io
from scipy import signal
from matplotlib import pyplot as plt
import math
dokmeh=[]
mat = scipy.io.loadmat('FREQUNCIES.mat')
f1209=mat.get('f1209')
f1336=mat.get('f1336')
f1477=mat.get('f1477')
f1633=mat.get('f1633')
f697=mat.get('f697')
f770=mat.get('f770')
f852=mat.get('f852_1')
f941=mat.get('f941')
L=len(data)
o=math.ceil(L/1000)
for i in range(o):
    q=1000*(i-1)
    p=1000*i-1
    data1=data[q:p]
    maxi=max(abs(data1))
    data1=data1/maxi
    f1=signal.lfilter(f1209[0,:],1,data1)
    f2=signal.lfilter(f1336[0,:],1,data1)
    f3=signal.lfilter(f1477[0,:],1,data1)
    f4=signal.lfilter(f1633[0,:],1,data1)
    f5=signal.lfilter(f697[0,:],1,data1)
    f6=signal.lfilter(f770[0,:],1,data1)
    f7=signal.lfilter(f852[0,:],1,data1)
    f8=signal.lfilter(f941[0,:],1,data1)
    Y1=np.fft.fft(f1)
    Y2=np.fft.fft(f2)
    Y3=np.fft.fft(f3)
    Y4=np.fft.fft(f4)
    Y5=np.fft.fft(f5)
    Y6=np.fft.fft(f6)
    Y7=np.fft.fft(f7)
    Y8=np.fft.fft(f8)
    L1=len(Y1)
    L2=len(Y2)
    L3=len(Y3)
    L4=len(Y4)
    L5=len(Y5)
    L6=len(Y6)
    L7=len(Y7)
    L8=len(Y8)
    P1 = abs(Y1/L1)
    P2 = abs(Y2/L2)
    P3 = abs(Y3/L3)
    P4 = abs(Y4/L4)
    P5 = abs(Y5/L5)
    P6 = abs(Y6/L6)
    P7 = abs(Y7/L7)
    P8 = abs(Y8/L8)
    col=[max(P1),max(P2),max(P3),max(P4)]
    row=[max(P5),max(P6),max(P7),max(P8)]
    mmco=max(col)
    mmro=max(row)
    if mmco>0.06 and mmro>0.06:
        mcol = col.index(mmco)         
        mrow = row.index(mmro)
        if mcol==0 and mrow==0:
            dokmeh=dokmeh+['1']
        elif mcol==0 and mrow==1:
            dokmeh=dokmeh+['4']
        elif mcol==0 and mrow==2:
            dokmeh=dokmeh+['7']
        elif mcol==0 and mrow==3:
            dokmeh=dokmeh+['*']
        elif mcol==1 and mrow==0:
            dokmeh=dokmeh+['2']
        elif mcol==1 and mrow==1:
            dokmeh=dokmeh+['5']
        elif mcol==1 and mrow==2:
            dokmeh=dokmeh+['8']
        elif mcol==1 and mrow==3:
            dokmeh=dokmeh+['0']
        elif mcol==2 and mrow==0:
            dokmeh=dokmeh+['3']
        elif mcol==2 and mrow==1:
            dokmeh=dokmeh+['6']
        elif mcol==2 and mrow==2:
            dokmeh=dokmeh+['9']
        elif mcol==2 and mrow==3:
            dokmeh=dokmeh+['#']
        elif mcol==3 and mrow==0:
            dokmeh=dokmeh+['A']
        elif mcol==3 and mrow==1:
            dokmeh=dokmeh+['B']
        elif mcol==3 and mrow==2:
            dokmeh=dokmeh+['C']
        elif mcol==3 and mrow==3:
            dokmeh=dokmeh+['D']
dokmeh = list(dict.fromkeys(dokmeh))
print(dokmeh)
# Out:
# ['#', 'A', '7', '*', '6', '0', '4', '5', '2', '9', '1', '8', 'C', '3', 'B', 'D']

# %% [markdown]
# # The Bottoms in SNR=30dB were ['#', 'A', '7', '*', '6', '0', '4', '5', '2', '9', '1', '8', 'C', '3', 'B', 'D']
